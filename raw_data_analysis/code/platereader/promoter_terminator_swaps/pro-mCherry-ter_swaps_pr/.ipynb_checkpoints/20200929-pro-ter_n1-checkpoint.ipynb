# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# makes figures look better in Jupyter
sns.set_context("talk")

# %%
import omniplate as om

# %%
p= om.platereader(wdir= 'data/')
# Out:
# omniplate version= 0.19
# Working directory is /Users/jamieauxillos/Desktop/Files to sort/Omniplate/20201002-proter/data/
# Files available are:
# ---
# 20201002-Pro-ter_mCherry-collection_n4.xlsx
# .DS_Store
# n5_pro-ter_contents.xls
# 20201027-Pro-ter_mCherry-collection_n6_withnewHSP-TOS_HSP3x.xlsx
# 20200930-Pro-ter_mCherry-collection_n2.xlsx
# ODcorrection_Raffinose_Haploid.txt
# n1-n4_pro-ter_contents.xls
# ODcorrection_Glucose_Diploid.txt
# 20201014-Pro-ter_mCherry-collection_n5_withnewHSP-TOS.xlsx
# ODcorrection_Glucose_Haploid.txt
# 20201001-Pro-ter_mCherry-collection_n3.xlsx
# 20200929-Pro-ter_mCherry-collection_n1.xlsx
# n6_pro-ter_lastplate_contents.xls
# ODcorrection_W303.txt

# %%
p.load('20200929-Pro-ter_mCherry-collection_n1.xlsx', 'n1-n4_pro-ter_contents.xls')
# Out:
# loading 20200929-Pro-ter_mCherry-collection_n1.xlsx
#
# Experiment: 20200929-Pro-ter_mCherry-collection_n1
# ---
# Conditions:
# 	 SC-URA
# Strains:
# 	 Null
# 	 POT1-ccdB
# 	 pCLN2-mCherry-tCLN2
# 	 pCLN2-mCherry-tHSP26
# 	 pCLN2-mCherry-tPAB1
# 	 pCLN2-mCherry-tPGK1
# 	 pCLN2-mCherry-tPMA1
# 	 pCLN2-mCherry-tRPS13
# 	 pCLN2-mCherry-tRPS3
# 	 pCLN2-mCherry-tSRO9
# 	 pCLN2-mCherry-tSUN4
# 	 pCLN2-mCherry-tTOS6
# 	 pHSP26-mCherry-tCLN2
# 	 pHSP26-mCherry-tHSP26
# 	 pHSP26-mCherry-tPAB1
# 	 pHSP26-mCherry-tPGK1
# 	 pHSP26-mCherry-tPMA1
# 	 pHSP26-mCherry-tRPS13
# 	 pHSP26-mCherry-tRPS3
# 	 pHSP26-mCherry-tSRO9
# 	 pHSP26-mCherry-tSUN4
# 	 pPGK1-mCherry-tCLN2
# 	 pPGK1-mCherry-tHSP26
# 	 pPGK1-mCherry-tPAB1
# 	 pPGK1-mCherry-tPGK1
# 	 pPGK1-mCherry-tPMA1
# 	 pPGK1-mCherry-tRPS13
# 	 pPGK1-mCherry-tRPS3
# 	 pPGK1-mCherry-tSRO9
# 	 pPGK1-mCherry-tSUN4
# 	 pPGK1-mCherry-tTOS6
# 	 pRPS13-mCherry-tCLN2
# 	 pRPS13-mCherry-tHSP26
# 	 pRPS13-mCherry-tPAB1
# 	 pRPS13-mCherry-tPGK1
# 	 pRPS13-mCherry-tPMA1
# 	 pRPS13-mCherry-tRPS13
# 	 pRPS13-mCherry-tRPS3
# 	 pRPS13-mCherry-tSRO9
# 	 pRPS13-mCherry-tSUN4
# 	 pRPS13-mCherry-tTOS6
# 	 pRPS3-mCherry-tCLN2
# 	 pRPS3-mCherry-tHSP26
# 	 pRPS3-mCherry-tPAB1
# 	 pRPS3-mCherry-tPGK1
# 	 pRPS3-mCherry-tPMA1
# 	 pRPS3-mCherry-tRPS13
# 	 pRPS3-mCherry-tRPS3
# 	 pRPS3-mCherry-tSRO9
# 	 pRPS3-mCherry-tSUN4
# 	 pRPS3-mCherry-tTOS6
# 	 pSRO9-mCherry-tCLN2
# 	 pSRO9-mCherry-tHSP26
# 	 pSRO9-mCherry-tPAB1
# 	 pSRO9-mCherry-tPGK1
# 	 pSRO9-mCherry-tPMA1
# 	 pSRO9-mCherry-tRPS13
# 	 pSRO9-mCherry-tRPS3
# 	 pSRO9-mCherry-tSRO9
# 	 pSRO9-mCherry-tSUN4
# 	 pSRO9-mCherry-tTOS6
# Data types:
# 	 OD
# 	 mCherry-100
# 	 mCherry-120
# Ignored wells:
# 	 None
#
# Warning: "null" has been changed to "Null" to avoid confusion with pandas.

# %%
p.r.head()
# Out:
#                                experiment condition strain      time well  \
# 0  20200929-Pro-ter_mCherry-collection_n1    SC-URA   Null  0.000000   A1
# 1  20200929-Pro-ter_mCherry-collection_n1    SC-URA   Null  0.211852   A1
# 2  20200929-Pro-ter_mCherry-collection_n1    SC-URA   Null  0.423676   A1
# 3  20200929-Pro-ter_mCherry-collection_n1    SC-URA   Null  0.635481   A1
# 4  20200929-Pro-ter_mCherry-collection_n1    SC-URA   Null  0.847287   A1
#
#        OD  mCherry-100  mCherry-120
# 0  0.0778          6.0         22.0
# 1  0.0772          7.0         20.0
# 2  0.0785          7.0         26.0
# 3  0.0781          3.0         17.0
# 4  0.0782          3.0         19.0

# %%
p.r.columns
# Out:
# Index(['experiment', 'condition', 'strain', 'time', 'well', 'OD',
#        'mCherry-100', 'mCherry-120'],
#       dtype='object')

# %%
p.s
# Out:
#                                   experiment condition               strain  \
# 0     20200929-Pro-ter_mCherry-collection_n1    SC-URA                 Null
# 1     20200929-Pro-ter_mCherry-collection_n1    SC-URA                 Null
# 2     20200929-Pro-ter_mCherry-collection_n1    SC-URA                 Null
# 3     20200929-Pro-ter_mCherry-collection_n1    SC-URA                 Null
# 4     20200929-Pro-ter_mCherry-collection_n1    SC-URA                 Null
# ...                                      ...       ...                  ...
# 4753  20200929-Pro-ter_mCherry-collection_n1    SC-URA  pSRO9-mCherry-tTOS6
# 4754  20200929-Pro-ter_mCherry-collection_n1    SC-URA  pSRO9-mCherry-tTOS6
# 4755  20200929-Pro-ter_mCherry-collection_n1    SC-URA  pSRO9-mCherry-tTOS6
# 4756  20200929-Pro-ter_mCherry-collection_n1    SC-URA  pSRO9-mCherry-tTOS6
# 4757  20200929-Pro-ter_mCherry-collection_n1    SC-URA  pSRO9-mCherry-tTOS6
#
#            time   OD mean  mCherry-100 mean  mCherry-120 mean    OD var  \
# 0      0.000000  0.077821          5.939394         21.818182  0.000002
# 1      0.211852  0.077900          6.696970         22.545455  0.000002
# 2      0.423676  0.078042          7.727273         22.636364  0.000002
# 3      0.635481  0.078094          4.363636         19.181818  0.000002
# 4      0.847287  0.078279          3.727273         19.212121  0.000002
# ...         ...       ...               ...               ...       ...
# 4753  15.462037  1.257800         13.000000         61.000000       NaN
# 4754  15.673843  1.257300         15.000000         61.000000       NaN
# 4755  15.885648  1.256600         14.000000         63.000000       NaN
# 4756  16.097454  1.256700         16.000000         60.000000       NaN
# 4757  16.309259  1.256300         15.000000         68.000000       NaN
#
#       mCherry-100 var  mCherry-120 var
# 0            0.683712         4.528409
# 1            0.842803         3.193182
# 2            0.642045         4.988636
# 3            0.613636         3.528409
# 4            0.704545         1.984848
# ...               ...              ...
# 4753              NaN              NaN
# 4754              NaN              NaN
# 4755              NaN              NaN
# 4756              NaN              NaN
# 4757              NaN              NaN
#
# [4758 rows x 10 columns]

# %%
p.plot(y= 'OD', plate= True)
p.plot(y= 'mCherry-100', plate= True)

# %%
p.correctOD()
# Out:
# 20200929-Pro-ter_mCherry-collection_n1 :: Correcting for media for OD in SC-URA
# GP Warning: large data set - 2574 datapoints - may slow optimisation and give memory issues
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c687bd785d2e> in <module>
# ----> 1 p.correctOD()
#
# ~/Desktop/Files to sort/Omniplate/20201002-proter/omniplate.py in correctOD(self, figs, correctmedia, commonmedia, mediafigs, experiments, experimentincludes, experimentexcludes, correctmediamean, correctmediaiskip)
#    1066                     self.correctmedia(datatypes= 'OD', mean= correctmediamean, figs= mediafigs, commonmedia= commonmedia,
#    1067                                       experiments= experiments, experimentincludes= experimentincludes, experimentexcludes= experimentexcludes,
# -> 1068                                       log= False, iskip= correctmediaiskip)
#    1069                     self.progress['ODcorrectedformedia'][exp]= True
#    1070                 # fit dilution data
#
# ~/Desktop/Files to sort/Omniplate/20201002-proter/omniplate.py in correctmedia(self, datatypes, mean, commonmedia, experiments, experimentincludes, experimentexcludes, conditions, conditionincludes, conditionexcludes, figs, noruns, exitearly, bd, results, log, iskip)
#    1170                     print(exp, ':: Correcting for media for', dtype, 'in', c)
#    1171                     cm= commonmedia if commonmedia else c
# -> 1172                     self.performmediacorrection(dtype, exp, c, figs, noruns, exitearly, bd, results, mean, cm, iskip)
#    1173                     self.sc.loc[(self.sc['condition'] == c) & (self.sc['experiment'] == exp),
#    1174                                 dtype + ' corrected for media']= True
#
# ~/Desktop/Files to sort/Omniplate/20201002-proter/omniplate.py in performmediacorrection(self, dtype, exp, condition, figs, noruns, exitearly, bd, results, mean, commonmedia, iskip)
#    1214                             t= t[::iskip]
#    1215                             data= data[::iskip]
# -> 1216                         f, fvar, gm= gu.smoothGP(t, data, bd= b, results= results)
#    1217                         self.progress['mediaGP'][exp][dtype][commonmedia]= gm
#    1218                         if figs:
#
# ~/Desktop/Files to sort/Omniplate/20201002-proter/genutils.py in smoothGP(x, y, xp, bd, noruns, exitearly, merrors, results)
#     541     if bd: b= mergedicts(original= b, update= bd)
#     542     g= gp.sqexpGP(b, x, y, merrors= merrors)
# --> 543     g.findhyperparameters(noruns, exitearly= exitearly)
#     544     if results: g.results()
#     545     g.predict(xp)
#
# ~/Desktop/Files to sort/Omniplate/20201002-proter/gaussianprocess.py in findhyperparameters(self, noruns, noinits, exitearly, stvals, optmethod, optmessages, quiet, linalgmax)
#     200                         from scipy.optimize import fmin_l_bfgs_b
#     201                         lthf[i,:], lmlml[i], dout= fmin_l_bfgs_b(self.nlml, lth, fprime= self.jacnlml,
# --> 202                                                                 bounds= b, disp= optmessages)
#     203                         success[i]= dout['warnflag'] + 1
#     204                         break
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     284         def func_and_grad(x):
#     285             f = fun(x, *args)
# --> 286             g = jac(x, *args)
#     287             return f, g
#     288
#
# ~/Desktop/Files to sort/Omniplate/20201002-proter/gaussianprocess.py in jacnlml(self, lth)
#     141         alal= np.outer(al, al)
#     142         Kinv= linalg.cho_solve(L, np.identity(len(x)))
# --> 143         return np.asarray([-0.5*np.trace(np.dot(alal - Kinv, kjac[:,:,i])) for i in range(len(lth))])
#     144
#     145
#
# ~/Desktop/Files to sort/Omniplate/20201002-proter/gaussianprocess.py in <listcomp>(.0)
#     141         alal= np.outer(al, al)
#     142         Kinv= linalg.cho_solve(L, np.identity(len(x)))
# --> 143         return np.asarray([-0.5*np.trace(np.dot(alal - Kinv, kjac[:,:,i])) for i in range(len(lth))])
#     144
#     145
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
p.plot(y= 'mCherry-100', by= 'well')

# %%
sns.relplot(x= 'time', y= 'OD', data= p.r, kind= 'line', hue= 'well', 
            col= 'strain')

# %%
p.getstats()

# %%
p.sc[['experiment','strain', 'max gr', 'max gr var']].head()

# %%
p.plot(y= 'gr', hue= 'strain')

# %%
p.correctauto(['mCherry-100'], refstrain= 'POT1-ccdB')

# %%
p.exportdf()

# %%
q= om.platereader(wdir= 'data/', ls= False)
q.importdf('20200929-Pro-ter_mCherry-collection_n1')

# %%
e= '20200929-Pro-ter_mCherry-collection_n1'
# store results as an array of dictionaries to eventually convert into a dataframe
results= []
for s in p.allstrains[e]:
        # find the time of local maximum growth rate for the condition
        tm= p.sc.query('strain == @s')['time of local max gr'].values[0]
        # take the relevant sub-dataframe for the condition
        df= p.s.query('strain == @s')
        # find GPF mean at time tm
        i= np.argmin(np.abs(df['time'].values - tm))
        results.append({'c-mCherry-100 per OD at max local gr' : df['c-mCherry-100perod'][df.index[i]],
                     'strain' : s})
# convert to dataframe
rdf= pd.DataFrame(results)
# add to existing dataframe by experiment, condition, and strain
p.sc= pd.merge(p.sc, rdf, how= 'outer')

# %%
#p.sc[['strain','c-mCherry-100 per OD at max local gr']].to_csv("n=1.csv")

# %%
#p.corrections[['strain','c-mCherry-100']].to_csv("n=1_c-mCherry-100.csv")

# %%
# plot results
#p.plot(x= 'strain', y= 'c-mCherry-100 per OD at max local gr', hue= 'strain',
#       strainexcludes=['Neg_POT1-ccdB_biorep1','Neg_POT1-ccdB_biorep2','Neg_POT1-ccdB_biorep3','Null'] )

# %%
#e= '20200116 - motif-mCherry-tRPS3trunc pRPS3 n=2'
# store results as an array of dictionaries to eventually convert into a dataframe
#results= []
#for s in p.allstrains[e]:
#        # find the time of local maximum growth rate for the condition
#        tm= p.sc.query('strain == @s')['time of local max gr'].values[0]
#        # take the relevant sub-dataframe for the condition
#        df= p.s.query('strain == @s')
#        # find GPF mean at time tm
#        i= np.argmin(np.abs(df['time'].values - tm))
#        results.append({'c-mCherry-100 per OD mean at max local gr' : df['c-mCherry-100perod mean'][df.index[i]],
#                     'strain' : s})
# convert to dataframe
#rdf= pd.DataFrame(results)
# add to existing dataframe by experiment, condition, and strain
#p.sc= pd.merge(p.sc, rdf, how= 'outer')
