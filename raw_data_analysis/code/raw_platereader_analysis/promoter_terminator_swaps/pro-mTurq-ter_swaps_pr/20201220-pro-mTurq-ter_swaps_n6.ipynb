# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# makes figures look better in Jupyter
sns.set_context("talk")

# %%
import sys 
from pathlib import Path 
sys.path.insert(0, str(Path.cwd().parents[1]) + "/omniplate_platereader_analysis_code")

# %%
import omniplate as om

# %%
p= om.platereader(wdir= '../../../../data/raw_platereader/promoter_terminator_swaps/mTurq_collection/')
# Out:
# omniplate version= 0.15
# Working directory is /home/dimmest-p/Documents/PhD/3UTR_motifs/motifPrediction/chimera_project_manuscript/raw_data_analysis/code/raw_platereader_analysis/promoter_terminator_swaps/pro-mTurq-ter_swaps_pr/../../../../data/raw_platereader/promoter_terminator_swaps/mTurq_collection/
# Files available are:
# ---
# 20201205-Pro-ter_mTurq2-collection_n6.xlsx
# 20201110-Pro-ter_mTurq2-collection_n1_s.json
# 20201110-Pro-ter_mTurq2-collection_n1_r.json
# 20201202-Pro-ter_mTurq2-collection_n4.xlsx
# ODcorrection_Glucose_Haploid.txt
# 20201126-Pro-ter_mTurq2-collection_n3.xlsx
# 20201204-Pro-ter_mTurq2-collection_n5.xlsx
# 20201112-pro-ter_mTurq_contents.xls
# 20201122-Pro-ter_mTurq2-collection_n2.xlsx
# 20201110-Pro-ter_mTurq2-collection_n1.xlsx
# 20201110-Pro-ter_mTurq2-collection_n1.log
# 20201110-Pro-ter_mTurq2-collection_n1_sc.json

# %%
p.load('20201205-Pro-ter_mTurq2-collection_n6.xlsx', '20201112-pro-ter_mTurq_contents.xls')
# Out:
# loading 20201205-Pro-ter_mTurq2-collection_n6.xlsx
#
# Experiment: 20201205-Pro-ter_mTurq2-collection_n6
# ---
# Conditions:
# 	 SC-URA
# Strains:
# 	 POT1-ccdB
# 	 null
# 	 pCLN2-mTurq-tCLN2
# 	 pCLN2-mTurq-tHSP26
# 	 pCLN2-mTurq-tPAB1
# 	 pCLN2-mTurq-tPGK1
# 	 pCLN2-mTurq-tPMA1_long
# 	 pCLN2-mTurq-tRPS13
# 	 pCLN2-mTurq-tRPS3
# 	 pCLN2-mTurq-tSRO9_long
# 	 pCLN2-mTurq-tSUN4
# 	 pCLN2-mTurq-tTOS6
# 	 pHSP26-mTurq-tCLN2
# 	 pHSP26-mTurq-tHSP26
# 	 pHSP26-mTurq-tPAB1
# 	 pHSP26-mTurq-tPGK1
# 	 pHSP26-mTurq-tPMA1_long
# 	 pHSP26-mTurq-tRPS13
# 	 pHSP26-mTurq-tRPS3
# 	 pHSP26-mTurq-tSRO9_long
# 	 pHSP26-mTurq-tSUN4
# 	 pHSP26-mTurq-tTOS6
# 	 pPGK1-mTurq-tCLN2
# 	 pPGK1-mTurq-tHSP26
# 	 pPGK1-mTurq-tPAB1
# 	 pPGK1-mTurq-tPGK1
# 	 pPGK1-mTurq-tPMA1_long
# 	 pPGK1-mTurq-tRPS13
# 	 pPGK1-mTurq-tRPS3
# 	 pPGK1-mTurq-tSRO9_long
# 	 pPGK1-mTurq-tSUN4
# 	 pPGK1-mTurq-tTOS6
# 	 pRPS13-mTurq-tCLN2
# 	 pRPS13-mTurq-tHSP26
# 	 pRPS13-mTurq-tPAB1
# 	 pRPS13-mTurq-tPGK1
# 	 pRPS13-mTurq-tPMA1_long
# 	 pRPS13-mTurq-tRPS13
# 	 pRPS13-mTurq-tRPS3
# 	 pRPS13-mTurq-tSRO9_long
# 	 pRPS13-mTurq-tSUN4
# 	 pRPS13-mTurq-tTOS6
# 	 pRPS3-mTurq-tCLN2
# 	 pRPS3-mTurq-tHSP26
# 	 pRPS3-mTurq-tPAB1
# 	 pRPS3-mTurq-tPGK1
# 	 pRPS3-mTurq-tPMA1_long
# 	 pRPS3-mTurq-tRPS13
# 	 pRPS3-mTurq-tRPS3
# 	 pRPS3-mTurq-tSRO9_long
# 	 pRPS3-mTurq-tSUN4
# 	 pRPS3-mTurq-tTOS6
# 	 pSRO9-mTurq-tCLN2
# 	 pSRO9-mTurq-tHSP26
# 	 pSRO9-mTurq-tPAB1
# 	 pSRO9-mTurq-tPGK1
# 	 pSRO9-mTurq-tPMA1_long
# 	 pSRO9-mTurq-tRPS13
# 	 pSRO9-mTurq-tRPS3
# 	 pSRO9-mTurq-tSRO9_long
# 	 pSRO9-mTurq-tSUN4
# 	 pSRO9-mTurq-tTOS6
# Data types:
# 	 OD
# 	 mTurq-80
# 	 mTurq-60
# Ignored wells:
# 	 None

# %%
p.r.head()

# %%
p.r.columns

# %%
p.s

# %%
p.plot(y= 'OD', plate= True)
p.plot(y= 'mTurq-60', plate= True)

# %%
p.correctOD()
# Out:
# 20201205-Pro-ter_mTurq2-collection_n6 :: Correcting for media for OD in SC-URA
# GP Warning: large data set - 2640 datapoints - may slow optimisation and give memory issues
#  Warning: linear algebra error - trying a different initial condition
# Fitting dilution data for OD correction for non-linearities
# Using ../../../../data/raw_platereader/promoter_terminator_swaps/mTurq_collection/ODcorrection_Glucose_Haploid.txt

# %%
p.plot(y= 'mTurq-60', by= 'well')

# %%
sns.relplot(x= 'time', y= 'OD', data= p.r, kind= 'line', hue= 'well', 
            col= 'strain')

# %%
p.getstats()
# Out:
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: POT1-ccdB in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 5.068694e+02
# hparam[0]= 2.321613e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.106219e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 6.296075e-04 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.406304e-01 +/- 7.724700e-03 [7.724700e-04]
#  time of max gr= 3.201955e+00 +/- 2.829746e-01 [2.829746e-02]
#   doubling time= 2.035953e+00 +/- 4.666835e-02 [4.666835e-03]
#          max OD= 6.794595e-01 +/- 3.821777e-03 [3.821777e-04]
#        lag time= 1.088922e+00 +/- 4.772941e-02 [4.772941e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pCLN2-mTurq-tCLN2 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.991718e+02
# hparam[0]= 5.118852e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.436411e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.449176e-01 +/- 2.972992e-03 [2.972992e-04]
#  time of max gr= 2.988072e+00 +/- 1.433002e-01 [1.433002e-02]
#   doubling time= 2.009751e+00 +/- 1.732486e-02 [1.732486e-03]
#          max OD= 6.597051e-01 +/- 7.968818e-04 [7.968818e-05]
#        lag time= 9.929422e-01 +/- 1.856070e-02 [1.856070e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pCLN2-mTurq-tHSP26 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.976164e+02
# hparam[0]= 3.750970e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.151907e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.581360e-01 +/- 4.011889e-03 [4.011889e-04]
#  time of max gr= 2.930895e+00 +/- 1.395743e-01 [1.395743e-02]
#   doubling time= 1.935673e+00 +/- 2.165759e-02 [2.165759e-03]
#          max OD= 6.820349e-01 +/- 9.179848e-04 [9.179848e-05]
#        lag time= 9.676026e-01 +/- 2.430705e-02 [2.430705e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pCLN2-mTurq-tPAB1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.923572e+02
# hparam[0]= 2.167581e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.007236e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.399116e-01 +/- 3.755380e-03 [3.755380e-04]
#  time of max gr= 2.888541e+00 +/- 1.421214e-01 [1.421214e-02]
#   doubling time= 2.039447e+00 +/- 2.252296e-02 [2.252296e-03]
#          max OD= 7.001036e-01 +/- 9.898054e-04 [9.898054e-05]
#        lag time= 9.946072e-01 +/- 2.428702e-02 [2.428702e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pCLN2-mTurq-tPGK1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3
-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pPGK1-mTurq-tRPS3 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.904634e+02
# hparam[0]= 2.319450e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.019984e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.478725e-01 +/- 3.450265e-03 [3.450265e-04]
#  time of max gr= 2.920305e+00 +/- 2.782057e-01 [2.782057e-02]
#   doubling time= 1.992728e+00 +/- 1.973517e-02 [1.973517e-03]
#          max OD= 6.835047e-01 +/- 9.652823e-04 [9.652823e-05]
#        lag time= 1.051464e+00 +/- 2.041846e-02 [2.041846e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pPGK1-mTurq-tSRO9_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.928764e+02
# hparam[0]= 2.311827e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.058660e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.524004e-01 +/- 3.663508e-03 [3.663508e-04]
#  time of max gr= 2.888541e+00 +/- 1.906381e-01 [1.906381e-02]
#   doubling time= 1.967143e+00 +/- 2.046730e-02 [2.046730e-03]
#          max OD= 7.096041e-01 +/- 1.059940e-03 [1.059940e-04]
#        lag time= 1.008556e+00 +/- 2.130280e-02 [2.130280e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pPGK1-mTurq-tSUN4 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.900778e+02
# hparam[0]= 8.997310e-01 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.623365e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.290994e-01 +/- 2.703230e-03 [2.703230e-04]
#  time of max gr= 2.996542e+00 +/- 2.402875e-01 [2.402875e-02]
#   doubling time= 2.106337e+00 +/- 1.732981e-02 [1.732981e-03]
#          max OD= 6.925419e-01 +/- 1.081957e-03 [1.081957e-04]
#        lag time= 9.861804e-01 +/- 1.654918e-02 [1.654918e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pPGK1-mTurq-tTOS6 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.953808e+02
# hparam[0]= 1.984150e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.084597e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.370527e-01 +/- 3.434230e-03 [3.434230e-04]
#  time of max gr= 2.888541e+00 +/- 2.042659e-01 [2.042659e-02]
#   doubling time= 2.056708e+00 +/- 2.094236e-02 [2.094236e-03]
#          max OD= 6.808224e-01 +/- 9.840580e-04 [9.840580e-05]
#        lag time= 8.939972e-01 +/- 2.348466e-02 [2.348466e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS13-mTurq-tCLN2 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.009379e+02
# hparam[0]= 2.762687e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.228246e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.506938e-01 +/- 3.554843e-03 [3.554843e-04]
#  time of max gr= 2.935130e+00 +/- 1.918108e-01 [1.918108e-02]
#   doubling time= 1.976706e+00 +/- 2.010821e-02 [2.010821e-03]
#          max OD= 6.741290e-01 +/- 7.272445e-04 [7.272445e-05]
#        lag time= 1.010399e+00 +/- 2.148478e-02 [2.148478e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS13-mTurq-tHSP26 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
#  Warning: optimization of hyperparameters failed at run 1
#  Warning: optimization of hyperparameters failed at run 2
# log(max likelihood)= 2.970557e+02
# hparam[0]= 6.884174e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.622202e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.492232e-01 +/- 2.806573e-03 [2.806573e-04]
#  time of max gr= 2.789010e+00 +/- 1.798284e-01 [1.798284e-02]
#   doubling time= 1.984953e+00 +/- 1.589470e-02 [1.589470e-03]
#          max OD= 6.758373e-01 +/- 8.368055e-04 [8.368055e-05]
#        lag time= 9.123609e-01 +/- 1.753515e-02 [1.753515e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS13-mTurq-tPAB1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.978035e+02
# hparam[0]= 2.380070e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.139008e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.655098e-01 +/- 3.416921e-03 [3.416921e-04]
#  time of max gr= 2.861011e+00 +/- 1.451654e-01 [1.451654e-02]
#   doubling time= 1.896551e+00 +/- 1.771850e-02 [1.771850e-03]
#          max OD= 6.824613e-01 +/- 8.952355e-04 [8.952355e-05]
#        lag time= 9.870947e-01 +/- 1.952171e-02 [1.952171e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS13-mTurq-tPGK1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.972331e+02
# hparam[0]= 1.905597e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.043773e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3
-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS3-mTurq-tHSP26 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 1.867627e+02
# hparam[0]= 2.497435e+01 [1.000000e-05, 1.000000e+05]
# hparam[1]= 6.844937e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.979830e-04 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.888099e-01 +/- 1.605323e-02 [1.605323e-03]
#  time of max gr= 2.789010e+00 +/- 5.222114e-01 [5.222114e-02]
#   doubling time= 1.785677e+00 +/- 7.127459e-02 [7.127459e-03]
#          max OD= 6.904565e-01 +/- 3.591956e-03 [3.591956e-04]
#        lag time= 1.049035e+00 +/- 9.748734e-02 [9.748734e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS3-mTurq-tPAB1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.960228e+02
# hparam[0]= 2.437348e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.101656e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.604915e-01 +/- 3.258708e-03 [3.258708e-04]
#  time of max gr= 2.772068e+00 +/- 2.055243e-01 [2.055243e-02]
#   doubling time= 1.922941e+00 +/- 1.734387e-02 [1.734387e-03]
#          max OD= 6.783711e-01 +/- 7.644664e-04 [7.644664e-05]
#        lag time= 8.697018e-01 +/- 1.838528e-02 [1.838528e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS3-mTurq-tPGK1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.968532e+02
# hparam[0]= 2.408249e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.066390e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.666552e-01 +/- 3.660431e-03 [3.660431e-04]
#  time of max gr= 2.835599e+00 +/- 1.609859e-01 [1.609859e-02]
#   doubling time= 1.890649e+00 +/- 1.886585e-02 [1.886585e-03]
#          max OD= 6.825953e-01 +/- 9.077325e-04 [9.077325e-05]
#        lag time= 9.815145e-01 +/- 2.050833e-02 [2.050833e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS3-mTurq-tPMA1_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.943572e+02
# hparam[0]= 3.240000e+02 [1.000000e-05, 1.000000e+05]
# hparam[1]= 3.290926e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.464929e-01 +/- 3.051862e-03 [3.051862e-04]
#  time of max gr= 2.994425e+00 +/- 2.031636e-01 [2.031636e-02]
#   doubling time= 2.000621e+00 +/- 1.759540e-02 [1.759540e-03]
#          max OD= 7.018562e-01 +/- 9.344401e-04 [9.344401e-05]
#        lag time= 8.970502e-01 +/- 1.880845e-02 [1.880845e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS3-mTurq-tRPS13 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.942592e+02
# hparam[0]= 3.956442e+03 [1.000000e-05, 1.000000e+05]
# hparam[1]= 5.387827e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.558813e-01 +/- 2.904833e-03 [2.904833e-04]
#  time of max gr= 2.943601e+00 +/- 1.759079e-01 [1.759079e-02]
#   doubling time= 1.947822e+00 +/- 1.592419e-02 [1.592419e-03]
#          max OD= 6.898160e-01 +/- 8.509105e-04 [8.509105e-05]
#        lag time= 9.275617e-01 +/- 1.749297e-02 [1.749297e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS3-mTurq-tRPS3 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.919452e+02
# hparam[0]= 2.038600e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.013231e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.602985e-01 +/- 4.026146e-03 [4.026146e-04]
#  time of max gr= 2.736068e+00 +/- 2.046168e-01 [2.046168e-02]
#   doubling time= 1.924053e+00 +/- 2.137320e-02 [2.137320e-03]
#          max OD= 7.467347e-01 +/- 1.241578e-03 [1.241578e-04]
#        lag time= 9.442733e-01 +/- 2.099129e-02 [2.099129e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS3-mTurq-tSRO9_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.448756e+02
# hparam[0]= 7.390352e+02 [1.000000e-05, 1.000000e+05]
# hparam[1]= 4.085503e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 7.694481e-05 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.660901e-01 +/- 4.878509e-03 [4.878509e-04]
#  time of max gr= 2.975366e+00 +/- 1.781243e-01 [1.781243e-02]
#   doubling time= 1.893715e+00 +/- 2.522712e-02 [2.522712e-03]
#          max OD= 6.791234e-01 +/- 2.254433e-03 [2.254433e-04]
#        lag time= 9.227660e-01 +/- 3.568575e-02 [3.568575e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS3-mTurq-tSUN4 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.972974e+02
# hparam[0]= 9.439428e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.355415e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.541775e-01 +/- 3.379469e-03 [3.379469e-04]
#  time of max gr= 3.185014e+00 +/- 2.115954e-01 [2.115954e-02]
#   doubling time= 1.957239e+00 +/- 1.862112e-02 [1.862112e-03]
#          max OD= 6.915480e-01 +/- 9.845764e-04 [9.845764e-05]
#        lag time= 1.037290e+00 +/- 2.243264e-02 [2.243264e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pRPS3-mTurq-tTOS6 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.991877e+02
# hparam[0]= 2.580039e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.175649e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.628992e-01 +/- 3.440075e-03 [3.440075e-04]
#  time of max gr= 2.969013e+00 +/- 2.030763e-01 [2.030763e-02]
#   doubling time= 1.910198e+00 +/- 1.804472e-02 [1.804472e-03]
#          max OD= 6.850771e-01 +/- 8.914816e-04 [8.914816e-05]
#        lag time= 9.754773e-01 +/- 2.125541e-02 [2.125541e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pSRO9-mTurq-tCLN2 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.008795e+02
# hparam[0]= 3.826567e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.319361e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.480927e-01 +/- 2.688319e-03 [2.688319e-04]
#  time of max gr= 2.943600e+00 +/- 2.169970e-01 [2.169970e-02]
#   doubling time= 1.991390e+00 +/- 1.535298e-02 [1.535298e-03]
#          max OD= 6.514629e-01 +/- 7.751618e-04 [7.751618e-05]
#        lag time= 9.372693e-01 +/- 1.796360e-02 [1.796360e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pSRO9-mTurq-tHSP26 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.952092e+02
# hparam[0]= 2.191193e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.024966e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.543132e-01 +/- 3.749326e-03 [3.749326e-04]
#  time of max gr= 2.784775e+00 +/- 1.704046e-01 [1.704046e-02]
#   doubling time= 1.956532e+00 +/- 2.074480e-02 [2.074480e-03]
#          max OD= 7.414418e-01 +/- 9.366309e-04 [9.366309e-05]
#        lag time= 9.007191e-01 +/- 2.106035e-02 [2.106035e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pSRO9-mTurq-tPAB1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.973118e+02
# hparam[0]= 3.069325e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.160366e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.556629e-01 +/- 3.373163e-03 [3.373163e-04]
#  time of max gr= 2.854658e+00 +/- 1.808853e-01 [1.808853e-02]
#   doubling time= 1.949063e+00 +/- 1.841623e-02 [1.841623e-03]
#          max OD= 6.755915e-01 +/- 8.451850e-04 [8.451850e-05]
#        lag time= 9.142844e-01 +/- 1.974363e-02 [1.974363e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pSRO9-mTurq-tPGK1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.890937e+02
# hparam[0]= 2.453721e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.081244e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.552380e-01 +/- 3.204204e-03 [3.204204e-04]
#  time of max gr= 2.994425e+00 +/- 1.941335e-01 [1.941335e-02]
#   doubling time= 1.951378e+00 +/- 1.756806e-02 [1.756806e-03]
#          max OD= 6.779697e-01 +/- 9.015672e-04 [9.015672e-05]
#        lag time= 1.015350e+00 +/- 1.908424e-02 [1.908424e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pSRO9-mTurq-tPMA1_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.936768e+02
# hparam[0]= 8.276625e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.736815e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.227909e-01 +/- 2.771416e-03 [2.771416e-04]
#  time of max gr= 3.318425e+00 +/- 1.499037e-01 [1.499037e-02]
#   doubling time= 2.147515e+00 +/- 1.842226e-02 [1.842226e-03]
#          max OD= 6.709859e-01 +/- 8.143372e-04 [8.143372e-05]
#        lag time= 9.603723e-01 +/- 2.227511e-02 [2.227511e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pSRO9-mTurq-tRPS13 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.920071e+02
# hparam[0]= 1.047235e+01 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.732332e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.328038e-01 +/- 3.042049e-03 [3.042049e-04]
#  time of max gr= 3.233720e+00 +/- 2.177262e-01 [2.177262e-02]
#   doubling time= 2.082923e+00 +/- 1.895194e-02 [1.895194e-03]
#          max OD= 7.456748e-01 +/- 9.111398e-04 [9.111398e-05]
#        lag time= 1.037294e+00 +/- 2.093010e-02 [2.093010e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pSRO9-mTurq-tRPS3 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.924072e+02
# hparam[0]= 3.312254e+02 [1.000000e-05, 1.000000e+05]
# hparam[1]= 3.361712e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.435389e-01 +/- 3.022207e-03 [3.022207e-04]
#  time of max gr= 3.106662e+00 +/- 1.614295e-01 [1.614295e-02]
#   doubling time= 2.017823e+00 +/- 1.775508e-02 [1.775508e-03]
#          max OD= 7.033041e-01 +/- 8.252110e-04 [8.252110e-05]
#        lag time= 9.383504e-01 +/- 2.217247e-02 [2.217247e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pSRO9-mTurq-tSRO9_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.956909e+02
# hparam[0]= 3.585888e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.306448e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.420872e-01 +/- 2.960912e-03 [2.960912e-04]
#  time of max gr= 3.244309e+00 +/- 1.818705e-01 [1.818705e-02]
#   doubling time= 2.026382e+00 +/- 1.754216e-02 [1.754216e-03]
#          max OD= 6.722808e-01 +/- 7.895840e-04 [7.895840e-05]
#        lag time= 1.014923e+00 +/- 2.060093e-02 [2.060093e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pSRO9-mTurq-tSUN4 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.870721e+02
# hparam[0]= 2.975600e+03 [1.000000e-05, 1.000000e+05]
# hparam[1]= 5.156101e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.411790e-01 +/- 3.319956e-03 [3.319956e-04]
#  time of max gr= 3.049484e+00 +/- 1.894097e-01 [1.894097e-02]
#   doubling time= 2.031815e+00 +/- 1.971167e-02 [1.971167e-03]
#          max OD= 6.669723e-01 +/- 8.772060e-04 [8.772060e-05]
#        lag time= 1.009304e+00 +/- 2.165789e-02 [2.165789e-03]
# Fitting OD for 20201205-Pro-ter_mTurq2-collection_n6:: pSRO9-mTurq-tTOS6 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.976237e+02
# hparam[0]= 1.528173e+01 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.970450e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.306044e-01 +/- 3.049818e-03 [3.049818e-04]
#  time of max gr= 3.053720e+00 +/- 1.725085e-01 [1.725085e-02]
#   doubling time= 2.096784e+00 +/- 1.931914e-02 [1.931914e-03]
#          max OD= 6.636917e-01 +/- 7.606155e-04 [7.606155e-05]
#        lag time= 1.032721e+00 +/- 1.998226e-02 [1.998226e-03]

# %%
p.sc[['experiment','strain', 'max gr', 'max gr var']].head()

# %%
p.plot(y= 'gr', hue= 'strain')

# %%
p.correctauto(['mTurq-60'], refstrain= 'POT1-ccdB')
# Out:
# Using POT1-ccdB as the reference
# Correcting autofluorescence
# 20201205-Pro-ter_mTurq2-collection_n6:: Processing reference strain POT1-ccdB for mTurq-60 in SC-URA

# %%
p.s[["experiment", "strain", "time", "OD mean", "c-mTurq-60", "c-mTurq-60perod", "gr"]].to_csv("../../../../data/norm_platereader/promoter_terminator_swaps/mTurq_collection/pro-mTurq-ter_swaps_OD_and_mTurq.csv", mode = "a")
p.sc[["experiment", "strain", "max gr", "time of max gr"]].to_csv("../../../../data/norm_platereader/promoter_terminator_swaps/mTurq_collection/pro-mTurq-ter_swaps_max_gr.csv", mode = "a")

# %%
p.exportdf()

# %%
q= om.platereader(wdir= 'data/', ls= False)
q.importdf('20201205-Pro-ter_mTurq2-collection_n6')

# %%
e= '20201205-Pro-ter_mTurq2-collection_n6'
# store results as an array of dictionaries to eventually convert into a dataframe
results= []
for s in p.allstrains[e]:
        # find the time of local maximum growth rate for the condition
        tm= p.sc.query('strain == @s')['time of local max gr'].values[0]
        # take the relevant sub-dataframe for the condition
        df= p.s.query('strain == @s')
        # find GPF mean at time tm
        i= np.argmin(np.abs(df['time'].values - tm))
        results.append({'c-mTurq-60 per OD at max local gr' : df['c-mTurq-60perod'][df.index[i]],
                     'strain' : s})
# convert to dataframe
rdf= pd.DataFrame(results)
# add to existing dataframe by experiment, condition, and strain
p.sc= pd.merge(p.sc, rdf, how= 'outer')

# %%
p.sc[['strain','c-mTurq-60 per OD at max local gr']].to_csv("../../../../data/norm_platereader/promoter_terminator_swaps/mTurq_collection/pro-mTurq-ter_swaps_n=6.csv")
