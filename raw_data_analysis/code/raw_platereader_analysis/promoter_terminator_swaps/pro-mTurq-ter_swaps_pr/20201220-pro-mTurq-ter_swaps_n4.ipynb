# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# makes figures look better in Jupyter
sns.set_context("talk")

# %%
import sys 
from pathlib import Path 
sys.path.insert(0, str(Path.cwd().parents[1]) + "/omniplate_platereader_analysis_code")

# %%
import omniplate as om

# %%
p= om.platereader(wdir= '../../../../data/raw_platereader/promoter_terminator_swaps/mTurq_collection/')
# Out:
# omniplate version= 0.15
# Working directory is /home/dimmest-p/Documents/PhD/3UTR_motifs/motifPrediction/chimera_project_manuscript/raw_data_analysis/code/raw_platereader_analysis/promoter_terminator_swaps/pro-mTurq-ter_swaps_pr/../../../../data/raw_platereader/promoter_terminator_swaps/mTurq_collection/
# Files available are:
# ---
# 20201205-Pro-ter_mTurq2-collection_n6.xlsx
# 20201110-Pro-ter_mTurq2-collection_n1_s.json
# 20201110-Pro-ter_mTurq2-collection_n1_r.json
# 20201202-Pro-ter_mTurq2-collection_n4.xlsx
# ODcorrection_Glucose_Haploid.txt
# 20201126-Pro-ter_mTurq2-collection_n3.xlsx
# 20201204-Pro-ter_mTurq2-collection_n5.xlsx
# 20201112-pro-ter_mTurq_contents.xls
# 20201122-Pro-ter_mTurq2-collection_n2.xlsx
# 20201110-Pro-ter_mTurq2-collection_n1.xlsx
# 20201110-Pro-ter_mTurq2-collection_n1.log
# 20201110-Pro-ter_mTurq2-collection_n1_sc.json

# %%
p.load('20201202-Pro-ter_mTurq2-collection_n4.xlsx', '20201112-pro-ter_mTurq_contents.xls')
# Out:
# loading 20201202-Pro-ter_mTurq2-collection_n4.xlsx
#
# Experiment: 20201202-Pro-ter_mTurq2-collection_n4
# ---
# Conditions:
# 	 SC-URA
# Strains:
# 	 POT1-ccdB
# 	 null
# 	 pCLN2-mTurq-tCLN2
# 	 pCLN2-mTurq-tHSP26
# 	 pCLN2-mTurq-tPAB1
# 	 pCLN2-mTurq-tPGK1
# 	 pCLN2-mTurq-tPMA1_long
# 	 pCLN2-mTurq-tRPS13
# 	 pCLN2-mTurq-tRPS3
# 	 pCLN2-mTurq-tSRO9_long
# 	 pCLN2-mTurq-tSUN4
# 	 pCLN2-mTurq-tTOS6
# 	 pHSP26-mTurq-tCLN2
# 	 pHSP26-mTurq-tHSP26
# 	 pHSP26-mTurq-tPAB1
# 	 pHSP26-mTurq-tPGK1
# 	 pHSP26-mTurq-tPMA1_long
# 	 pHSP26-mTurq-tRPS13
# 	 pHSP26-mTurq-tRPS3
# 	 pHSP26-mTurq-tSRO9_long
# 	 pHSP26-mTurq-tSUN4
# 	 pHSP26-mTurq-tTOS6
# 	 pPGK1-mTurq-tCLN2
# 	 pPGK1-mTurq-tHSP26
# 	 pPGK1-mTurq-tPAB1
# 	 pPGK1-mTurq-tPGK1
# 	 pPGK1-mTurq-tPMA1_long
# 	 pPGK1-mTurq-tRPS13
# 	 pPGK1-mTurq-tRPS3
# 	 pPGK1-mTurq-tSRO9_long
# 	 pPGK1-mTurq-tSUN4
# 	 pPGK1-mTurq-tTOS6
# 	 pRPS13-mTurq-tCLN2
# 	 pRPS13-mTurq-tHSP26
# 	 pRPS13-mTurq-tPAB1
# 	 pRPS13-mTurq-tPGK1
# 	 pRPS13-mTurq-tPMA1_long
# 	 pRPS13-mTurq-tRPS13
# 	 pRPS13-mTurq-tRPS3
# 	 pRPS13-mTurq-tSRO9_long
# 	 pRPS13-mTurq-tSUN4
# 	 pRPS13-mTurq-tTOS6
# 	 pRPS3-mTurq-tCLN2
# 	 pRPS3-mTurq-tHSP26
# 	 pRPS3-mTurq-tPAB1
# 	 pRPS3-mTurq-tPGK1
# 	 pRPS3-mTurq-tPMA1_long
# 	 pRPS3-mTurq-tRPS13
# 	 pRPS3-mTurq-tRPS3
# 	 pRPS3-mTurq-tSRO9_long
# 	 pRPS3-mTurq-tSUN4
# 	 pRPS3-mTurq-tTOS6
# 	 pSRO9-mTurq-tCLN2
# 	 pSRO9-mTurq-tHSP26
# 	 pSRO9-mTurq-tPAB1
# 	 pSRO9-mTurq-tPGK1
# 	 pSRO9-mTurq-tPMA1_long
# 	 pSRO9-mTurq-tRPS13
# 	 pSRO9-mTurq-tRPS3
# 	 pSRO9-mTurq-tSRO9_long
# 	 pSRO9-mTurq-tSUN4
# 	 pSRO9-mTurq-tTOS6
# Data types:
# 	 OD
# 	 mTurq-80
# 	 mTurq-60
# Ignored wells:
# 	 None

# %%
#p.r.head()

# %%
#p.r.columns

# %%
#p.s

# %%
#p.plot(y= 'OD', plate= True)
#p.plot(y= 'mTurq-60', plate= True)

# %%
p.correctOD()
# Out:
# 20201202-Pro-ter_mTurq2-collection_n4 :: Correcting for media for OD in SC-URA
# GP Warning: large data set - 2640 datapoints - may slow optimisation and give memory issues
# Fitting dilution data for OD correction for non-linearities
# Using ../../../../data/raw_platereader/promoter_terminator_swaps/mTurq_collection/ODcorrection_Glucose_Haploid.txt

# %%
#p.plot(y= 'mTurq-60', by= 'well')

# %%
#sns.relplot(x= 'time', y= 'OD', data= p.r, kind= 'line', hue= 'well', 
           # col= 'strain')
# Out:
#   Input In [12]
#     col= 'strain')
#     ^
# IndentationError: unexpected indent

# %%
p.getstats()
# Out:
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: POT1-ccdB in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 4.985187e+02
# hparam[0]= 2.212589e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.019183e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 6.670761e-04 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.796611e-01 +/- 7.554142e-03 [7.554142e-04]
#  time of max gr= 3.068725e+00 +/- 2.653483e-01 [2.653483e-02]
#   doubling time= 1.826424e+00 +/- 3.638293e-02 [3.638293e-03]
#          max OD= 7.301117e-01 +/- 4.392029e-03 [4.392029e-04]
#        lag time= 1.032823e+00 +/- 5.180347e-02 [5.180347e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pCLN2-mTurq-tCLN2 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.829156e+02
# hparam[0]= 2.861043e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.860708e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.679524e-01 +/- 3.407884e-03 [3.407884e-04]
#  time of max gr= 2.522339e+00 +/- 2.453230e-01 [2.453230e-02]
#   doubling time= 1.883957e+00 +/- 1.743573e-02 [1.743573e-03]
#          max OD= 7.591114e-01 +/- 1.051425e-03 [1.051425e-04]
#        lag time= 6.905615e-01 +/- 1.866696e-02 [1.866696e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pCLN2-mTurq-tHSP26 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.810017e+02
# hparam[0]= 2.024848e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.079012e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.831326e-01 +/- 3.379061e-03 [3.379061e-04]
#  time of max gr= 2.865418e+00 +/- 2.169143e-01 [2.169143e-02]
#   doubling time= 1.809298e+00 +/- 1.594983e-02 [1.594983e-03]
#          max OD= 7.372589e-01 +/- 9.662534e-04 [9.662534e-05]
#        lag time= 6.940258e-01 +/- 2.121709e-02 [2.121709e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pCLN2-mTurq-tPAB1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.716512e+02
# hparam[0]= 2.828615e+02 [1.000000e-05, 1.000000e+05]
# hparam[1]= 2.644005e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3
-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pPGK1-mTurq-tRPS13 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.516515e+02
# hparam[0]= 2.603325e+03 [1.000000e-05, 1.000000e+05]
# hparam[1]= 5.765879e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.759125e-01 +/- 2.436154e-03 [2.436154e-04]
#  time of max gr= 2.988249e+00 +/- 1.464026e-01 [1.464026e-02]
#   doubling time= 1.843983e+00 +/- 1.194157e-02 [1.194157e-03]
#          max OD= 7.862868e-01 +/- 1.388604e-03 [1.388604e-04]
#        lag time= 8.759952e-01 +/- 1.536621e-02 [1.536621e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pPGK1-mTurq-tRPS3 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.850539e+02
# hparam[0]= 4.068399e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.187012e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.808007e-01 +/- 3.277372e-03 [3.277372e-04]
#  time of max gr= 2.990367e+00 +/- 2.123699e-01 [2.123699e-02]
#   doubling time= 1.820371e+00 +/- 1.565722e-02 [1.565722e-03]
#          max OD= 7.570237e-01 +/- 1.251611e-03 [1.251611e-04]
#        lag time= 8.626687e-01 +/- 2.137645e-02 [2.137645e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pPGK1-mTurq-tSRO9_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
#  Warning: optimization of hyperparameters failed at run 1
# log(max likelihood)= 2.629859e+02
# hparam[0]= 4.449490e-01 [1.000000e-05, 1.000000e+05]
# hparam[1]= 7.202052e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.003856e-05 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.743186e-01 +/- 3.737192e-03 [3.737192e-04]
#  time of max gr= 3.106845e+00 +/- 2.160860e-01 [2.160860e-02]
#   doubling time= 1.851942e+00 +/- 1.847073e-02 [1.847073e-03]
#          max OD= 7.740633e-01 +/- 1.207243e-03 [1.207243e-04]
#        lag time= 9.033796e-01 +/- 2.327652e-02 [2.327652e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pPGK1-mTurq-tSUN4 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.654100e+02
# hparam[0]= 1.001719e+01 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.273251e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.290993e-05 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.631237e-01 +/- 4.157111e-03 [4.157111e-04]
#  time of max gr= 3.274149e+00 +/- 2.548735e-01 [2.548735e-02]
#   doubling time= 1.909095e+00 +/- 2.179358e-02 [2.179358e-03]
#          max OD= 7.384420e-01 +/- 1.232966e-03 [1.232966e-04]
#        lag time= 1.034548e+00 +/- 2.853489e-02 [2.853489e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pPGK1-mTurq-tTOS6 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.828389e+02
# hparam[0]= 1.938370e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.956654e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.641035e-01 +/- 3.483001e-03 [3.483001e-04]
#  time of max gr= 2.926834e+00 +/- 2.268693e-01 [2.268693e-02]
#   doubling time= 1.903883e+00 +/- 1.814486e-02 [1.814486e-03]
#          max OD= 7.427620e-01 +/- 1.146317e-03 [1.146317e-04]
#        lag time= 9.129786e-01 +/- 2.314843e-02 [2.314843e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS13-mTurq-tCLN2 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.890874e+02
# hparam[0]= 2.718613e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.001471e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.961654e-01 +/- 4.017199e-03 [4.017199e-04]
#  time of max gr= 2.867536e+00 +/- 1.319836e-01 [1.319836e-02]
#   doubling time= 1.749821e+00 +/- 1.772062e-02 [1.772062e-03]
#          max OD= 7.821593e-01 +/- 1.164070e-03 [1.164070e-04]
#        lag time= 7.458569e-01 +/- 2.311897e-02 [2.311897e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS13-mTurq-tHSP26 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.802843e+02
# hparam[0]= 4.875272e+01 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.959162e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.950077e-01 +/- 3.596970e-03 [3.596970e-04]
#  time of max gr= 2.704467e+00 +/- 1.300495e-01 [1.300495e-02]
#   doubling time= 1.754914e+00 +/- 1.597245e-02 [1.597245e-03]
#          max OD= 7.724882e-01 +/- 1.182118e-03 [1.182118e-04]
#        lag time= 7.120717e-01 +/- 1.933634e-02 [1.933634e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS13-mTurq-tPAB1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
#  Warning: optimization of hyperparameters failed at run 1
#  Warning: optimization of hyperparameters failed at run 2
# log(max likelihood)= -1.280562e+02
# hparam[0]= 8.088562e-03 [1.000000e-05, 1.000000e+05]
# hparam[1]=
+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.709183e-01 +/- 3.039261e-03 [3.039261e-04]
#  time of max gr= 3.161907e+00 +/- 1.752901e-01 [1.752901e-02]
#   doubling time= 1.868858e+00 +/- 1.527434e-02 [1.527434e-03]
#          max OD= 7.258736e-01 +/- 1.042871e-03 [1.042871e-04]
#        lag time= 9.296244e-01 +/- 1.954482e-02 [1.954482e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS3-mTurq-tCLN2 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.796675e+02
# hparam[0]= 2.419384e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.023272e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.013237e-05 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 4.039391e-01 +/- 4.320516e-03 [4.320516e-04]
#  time of max gr= 2.829416e+00 +/- 1.253610e-01 [1.253610e-02]
#   doubling time= 1.716165e+00 +/- 1.828397e-02 [1.828397e-03]
#          max OD= 7.451785e-01 +/- 1.229664e-03 [1.229664e-04]
#        lag time= 7.657079e-01 +/- 2.408058e-02 [2.408058e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS3-mTurq-tHSP26 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
#  Warning: optimization of hyperparameters failed at run 1
# log(max likelihood)= 2.639096e+02
# hparam[0]= 2.056875e+02 [1.000000e-05, 1.000000e+05]
# hparam[1]= 2.576641e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.510724e-05 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.930446e-01 +/- 4.216659e-03 [4.216659e-04]
#  time of max gr= 2.797649e+00 +/- 1.535790e-01 [1.535790e-02]
#   doubling time= 1.763736e+00 +/- 1.891044e-02 [1.891044e-03]
#          max OD= 7.567299e-01 +/- 1.489647e-03 [1.489647e-04]
#        lag time= 7.243594e-01 +/- 2.472754e-02 [2.472754e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS3-mTurq-tPAB1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.842649e+02
# hparam[0]= 2.131194e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.702034e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.806785e-01 +/- 3.347466e-03 [3.347466e-04]
#  time of max gr= 2.738352e+00 +/- 2.036921e-01 [2.036921e-02]
#   doubling time= 1.820961e+00 +/- 1.602310e-02 [1.602310e-03]
#          max OD= 7.768184e-01 +/- 1.256344e-03 [1.256344e-04]
#        lag time= 7.118939e-01 +/- 2.131295e-02 [2.131295e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS3-mTurq-tPGK1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.842910e+02
# hparam[0]= 2.336630e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.038372e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.887634e-01 +/- 3.713101e-03 [3.713101e-04]
#  time of max gr= 2.988249e+00 +/- 1.743666e-01 [1.743666e-02]
#   doubling time= 1.783116e+00 +/- 1.698524e-02 [1.698524e-03]
#          max OD= 7.547179e-01 +/- 1.256071e-03 [1.256071e-04]
#        lag time= 8.004876e-01 +/- 2.174889e-02 [2.174889e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS3-mTurq-tPMA1_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.899338e+02
# hparam[0]= 6.022184e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.337042e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.840990e-01 +/- 3.287838e-03 [3.287838e-04]
#  time of max gr= 2.886596e+00 +/- 1.425533e-01 [1.425533e-02]
#   doubling time= 1.804738e+00 +/- 1.544658e-02 [1.544658e-03]
#          max OD= 7.484512e-01 +/- 1.054091e-03 [1.054091e-04]
#        lag time= 8.039034e-01 +/- 1.900169e-02 [1.900169e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS3-mTurq-tRPS13 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.708718e+02
# hparam[0]= 4.562678e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.275726e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.533488e-05 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.802383e-01 +/- 3.345511e-03 [3.345511e-04]
#  time of max gr= 2.926834e+00 +/- 1.650780e-01 [1.650780e-02]
#   doubling time= 1.823069e+00 +/- 1.600113e-02 [1.600113e-03]
#          max OD= 7.593291e-01 +/- 1.645360e-03 [1.645360e-04]
#        lag time= 8.424862e-01 +/- 2.213791e-02 [2.213791e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS3-mTurq-tRPS3 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.872535e+02
# hparam[0]= 2.441875e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.041587e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.948186e-01 +/- 3.543347e-03 [3.543347e-04]
#  time of max gr= 3.096256e+00 +/- 1.688388e-01 [1.688388e-02]
#   doubling time= 1.755751e+00 +/- 1.578265e-02 [1.578265e-03]
#          max OD= 7.826917e-01 +/- 1.235739e-03 [1.235739e-04]
#        lag time= 9.008971e-01 +/- 1.957739e-02 [1.957739e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS3-mTurq-tSRO9_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.920635e+02
# hparam[0]= 2.586109e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.987130e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.783179e-01 +/- 3.823303e-03 [3.823303e-04]
#  time of max gr= 3.077196e+00 +/- 2.019232e-01 [2.019232e-02]
#   doubling time= 1.832368e+00 +/- 1.842711e-02 [1.842711e-03]
#          max OD= 7.677178e-01 +/- 1.140647e-03 [1.140647e-04]
#        lag time= 8.640490e-01 +/- 2.365011e-02 [2.365011e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS3-mTurq-tSUN4 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.919245e+02
# hparam[0]= 2.403574e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.096881e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.754342e-01 +/- 3.198695e-03 [3.198695e-04]
#  time of max gr= 3.064489e+00 +/- 1.928341e-01 [1.928341e-02]
#   doubling time= 1.846389e+00 +/- 1.575749e-02 [1.575749e-03]
#          max OD= 7.285290e-01 +/- 1.092315e-03 [1.092315e-04]
#        lag time= 8.872303e-01 +/- 2.025524e-02 [2.025524e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pRPS3-mTurq-tTOS6 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.891963e+02
# hparam[0]= 4.657983e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.278631e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.833382e-01 +/- 3.259732e-03 [3.259732e-04]
#  time of max gr= 3.003074e+00 +/- 2.061545e-01 [2.061545e-02]
#   doubling time= 1.808318e+00 +/- 1.537988e-02 [1.537988e-03]
#          max OD= 7.257711e-01 +/- 1.187556e-03 [1.187556e-04]
#        lag time= 9.043166e-01 +/- 1.946427e-02 [1.946427e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pSRO9-mTurq-tCLN2 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.774528e+02
# hparam[0]= 2.263809e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.524041e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.878008e-01 +/- 3.856985e-03 [3.856985e-04]
#  time of max gr= 2.757411e+00 +/- 1.796495e-01 [1.796495e-02]
#   doubling time= 1.787557e+00 +/- 1.780160e-02 [1.780160e-03]
#          max OD= 7.551272e-01 +/- 1.094876e-03 [1.094876e-04]
#        lag time= 7.512972e-01 +/- 2.306097e-02 [2.306097e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pSRO9-mTurq-tHSP26 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.787077e+02
# hparam[0]= 1.943872e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 8.788156e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.825924e-01 +/- 4.060111e-03 [4.060111e-04]
#  time of max gr= 2.784943e+00 +/- 2.061437e-01 [2.061437e-02]
#   doubling time= 1.811916e+00 +/- 1.921967e-02 [1.921967e-03]
#          max OD= 7.446993e-01 +/- 1.258268e-03 [1.258268e-04]
#        lag time= 7.297184e-01 +/- 2.414045e-02 [2.414045e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pSRO9-mTurq-tPAB1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.858146e+02
# hparam[0]= 1.740547e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.933395e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.785553e-01 +/- 3.212859e-03 [3.212859e-04]
#  time of max gr= 2.615521e+00 +/- 2.955405e-01 [2.955405e-02]
#   doubling time= 1.831164e+00 +/- 1.552653e-02 [1.552653e-03]
#          max OD= 7.521860e-01 +/- 1.222216e-03 [1.222216e-04]
#        lag time= 6.038784e-01 +/- 2.178755e-02 [2.178755e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pSRO9-mTurq-tPGK1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.870739e+02
# hparam[0]= 4.522483e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.130526e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.824239e-01 +/- 3.928456e-03 [3.928456e-04]
#  time of max gr= 2.791296e+00 +/- 1.903174e-01 [1.903174e-02]
#   doubling time= 1.812701e+00 +/- 1.856992e-02 [1.856992e-03]
#          max OD= 7.495676e-01 +/- 1.151079e-03 [1.151079e-04]
#        lag time= 7.572495e-01 +/- 2.057539e-02 [2.057539e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pSRO9-mTurq-tPMA1_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.904302e+02
# hparam[0]= 9.466523e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.410804e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.616631e-01 +/- 3.642026e-03 [3.642026e-04]
#  time of max gr= 2.933187e+00 +/- 1.926479e-01 [1.926479e-02]
#   doubling time= 1.916749e+00 +/- 1.925460e-02 [1.925460e-03]
#          max OD= 7.362125e-01 +/- 1.233789e-03 [1.233789e-04]
#        lag time= 7.771838e-01 +/- 2.320204e-02 [2.320204e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pSRO9-mTurq-tRPS13 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.893893e+02
# hparam[0]= 9.039916e-01 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.147437e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.713111e-01 +/- 3.475323e-03 [3.475323e-04]
#  time of max gr= 2.950129e+00 +/- 1.619927e-01 [1.619927e-02]
#   doubling time= 1.866919e+00 +/- 1.742022e-02 [1.742022e-03]
#          max OD= 7.569600e-01 +/- 1.159515e-03 [1.159515e-04]
#        lag time= 8.167299e-01 +/- 2.069915e-02 [2.069915e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pSRO9-mTurq-tRPS3 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.703178e+02
# hparam[0]= 5.864177e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.184807e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.438108e-05 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.707911e-01 +/- 4.069735e-03 [4.069735e-04]
#  time of max gr= 2.634581e+00 +/- 2.401969e-01 [2.401969e-02]
#   doubling time= 1.869599e+00 +/- 2.045914e-02 [2.045914e-03]
#          max OD= 7.810088e-01 +/- 1.322374e-03 [1.322374e-04]
#        lag time= 6.630269e-01 +/- 2.463592e-02 [2.463592e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pSRO9-mTurq-tSRO9_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.815721e+02
# hparam[0]= 2.532207e+04 [1.000000e-05, 1.000000e+05]
# hparam[1]= 7.337562e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.697003e-01 +/- 3.251908e-03 [3.251908e-04]
#  time of max gr= 3.000956e+00 +/- 1.747776e-01 [1.747776e-02]
#   doubling time= 1.875034e+00 +/- 1.643914e-02 [1.643914e-03]
#          max OD= 7.469785e-01 +/- 1.146721e-03 [1.146721e-04]
#        lag time= 8.466489e-01 +/- 2.135535e-02 [2.135535e-03]
# Fitting OD for 20201202-Pro-ter_mTurq2-collection_n4:: pSRO9-mTurq-tSUN4 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.886052e+02
# hparam[0]= 4.936676e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.351357e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.657893e-01 +/- 3.240814e-03 [3.240814e-04]
#  time of max gr= 3.043311e+00 +/- 1.909644e-01 [1.909644e-02]
#   doubling time= 1.895084e+00 +/- 1.672634e-02 [1.672634e-03]
#          max OD= 7.293468e-01 +/- 1.317031e-03 [1.317031e-04]
#        lag time= 8.737874e-01 +/- 2.034727e-02 [2.034727e-03]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 p.getstats()
#
# File ~/Documents/PhD/3UTR_motifs/motifPrediction/chimera_project_manuscript/raw_data_analysis/code/raw_platereader_analysis/omniplate_platereader_analysis_code/omniplate.py:1373, in platereader.getstats(self, dtype, bd, cvfn, esterrs, noruns, exitearly, noinits, nosamples, iskip, stats, plotodgr, figs, experiments, experimentincludes, experimentexcludes, conditions, conditionincludes, conditionexcludes, strains, strainincludes, strainexcludes)
#    1371 sod= np.exp(fsample)
#    1372 integrand= lambda x: interpolate.interp1d(sod, gsample)(x)
# -> 1373 iresult= integrate.quad(integrand, np.min(sod), np.max(sod),
#    1374                          limit= 100, full_output= 1)[0]
#    1375 aa.append(iresult)
#    1376 ana.append(iresult/(np.max(sod) - np.min(sod)))
#
# File ~/miniconda3/envs/platereader-analysis/lib/python3.8/site-packages/scipy/integrate/quadpack.py:351, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     348 flip, a, b = b < a, min(a, b), max(a, b)
#     350 if weight is None:
# --> 351     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     352                    points)
#     353 else:
#     354     if points is not None:
#
# File ~/miniconda3/envs/platereader-analysis/lib/python3.8/site-packages/scipy/integrate/quadpack.py:463, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461 if points is None:
#     462     if infbounds == 0:
# --> 463         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464     else:
#     465         return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# File ~/Documents/PhD/3UTR_motifs/motifPrediction/chimera_project_manuscript/raw_data_analysis/code/raw_platereader_analysis/omniplate_platereader_analysis_code/omniplate.py:1372, in platereader.getstats.<locals>.<lambda>(x)
#    1370 for fsample, gsample in zip(np.transpose(fs), np.transpose(gs)):
#    1371     sod= np.exp(fsample)
# -> 1372     integrand= lambda x: interpolate.interp1d(sod, gsample)(x)
#    1373     iresult= integrate.quad(integrand, np.min(sod), np.max(sod),
#    1374                              limit= 100, full_output= 1)[0]
#    1375     aa.append(iresult)
#
# File ~/miniconda3/envs/platereader-analysis/lib/python3.8/site-packages/scipy/interpolate/interpolate.py:436, in interp1d.__init__(self, x, y, kind, axis, copy, bounds_error, fill_value, assume_sorted)
#     432 def __init__(self, x, y, kind='linear', axis=-1,
#     433              copy=True, bounds_error=None, fill_value=np.nan,
#     434              assume_sorted=False):
#     435     """ Initialize a 1-D linear interpolation class."""
# --> 436     _Interpolator1D.__init__(self, x, y, axis=axis)
#     438     self.bounds_error = bounds_error  # used by fill_value setter
#     439     self.copy = copy
#
# File ~/miniconda3/envs/platereader-analysis/lib/python3.8/site-packages/scipy/interpolate/polyint.py:54, in _Interpolator1D.__init__(self, xi, yi, axis)
#      52 self.dtype = None
#      53 if yi is not None:
# ---> 54     self._set_yi(yi, xi=xi, axis=axis)
#
# File ~/miniconda3/envs/platereader-analysis/lib/python3.8/site-packages/scipy/interpolate/polyint.py:128, in _Interpolator1D._set_yi(self, yi, xi, axis)
#     124     raise ValueError("x and y arrays must be equal in length along "
#     125                      "interpolation axis.")
#     127 self._y_axis = (axis % yi.ndim)
# --> 128 self._y_extra_shape = yi.shape[:self._y_axis]+yi.shape[self._y_axis+1:]
#     129 self.dtype = None
#     130 self._set_dtype(yi.dtype)
#
# KeyboardInterrupt:

# %%
#p.sc[['experiment','strain', 'max gr', 'max gr var']].head()

# %%
#p.plot(y= 'gr', hue= 'strain')

# %%
p.correctauto(['mTurq-60'], refstrain= 'POT1-ccdB')

# %%
p.s[["experiment", "strain", "time", "OD mean", "c-mTurq-60", "c-mTurq-60perod", "gr"]].to_csv("../../../../data/norm_platereader/promoter_terminator_swaps/mTurq_collection/pro-mTurq-ter_swaps_OD_and_mTurq.csv", mode = "a", header = "none")
p.sc[["experiment", "strain", "max gr", "time of max gr"]].to_csv("../../../../data/norm_platereader/promoter_terminator_swaps/mTurq_collection/pro-mTurq-ter_swaps_max_gr.csv", mode = "a", header = "none")

# %%
p.exportdf()

# %%
q= om.platereader(wdir= 'data/', ls= False)
q.importdf('20201202-Pro-ter_mTurq2-collection_n4')

# %%
e= '20201202-Pro-ter_mTurq2-collection_n4'
# store results as an array of dictionaries to eventually convert into a dataframe
results= []
for s in p.allstrains[e]:
        # find the time of local maximum growth rate for the condition
        tm= p.sc.query('strain == @s')['time of local max gr'].values[0]
        # take the relevant sub-dataframe for the condition
        df= p.s.query('strain == @s')
        # find GPF mean at time tm
        i= np.argmin(np.abs(df['time'].values - tm))
        results.append({'c-mTurq-60 per OD at max local gr' : df['c-mTurq-60perod'][df.index[i]],
                     'strain' : s})
# convert to dataframe
rdf= pd.DataFrame(results)
# add to existing dataframe by experiment, condition, and strain
p.sc= pd.merge(p.sc, rdf, how= 'outer')

# %%
p.sc[['strain','c-mTurq-60 per OD at max local gr']].to_csv("../../../../data/norm_platereader/promoter_terminator_swaps/mTurq_collection/pro-mTurq-ter_swaps_n=4.csv")
