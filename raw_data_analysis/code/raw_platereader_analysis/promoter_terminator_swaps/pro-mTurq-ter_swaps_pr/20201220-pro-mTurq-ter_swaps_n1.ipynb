# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import session_info

# makes figures look better in Jupyter
sns.set_context("talk")

# %%
import sys 
from pathlib import Path 
sys.path.insert(0, str(Path.cwd().parents[1]) + "/omniplate_platereader_analysis_code")

# %%
import omniplate as om
session_info
# Out:
# <module 'session_info' from '/home/dimmest-p/miniconda3/envs/platereader-analysis/lib/python3.8/site-packages/session_info/__init__.py'>

# %%
p= om.platereader(wdir= '../../../../data/raw_platereader/promoter_terminator_swaps/mTurq_collection/')
# Out:
# omniplate version= 0.15
# Working directory is /home/dimmest-p/Documents/PhD/3UTR_motifs/motifPrediction/chimera_project_manuscript/raw_data_analysis/code/raw_platereader_analysis/promoter_terminator_swaps/pro-mTurq-ter_swaps_pr/../../../../data/raw_platereader/promoter_terminator_swaps/mTurq_collection/
# Files available are:
# ---
# 20201205-Pro-ter_mTurq2-collection_n6.xlsx
# 20201110-Pro-ter_mTurq2-collection_n1_s.json
# 20201110-Pro-ter_mTurq2-collection_n1_r.json
# 20201202-Pro-ter_mTurq2-collection_n4.xlsx
# ODcorrection_Glucose_Haploid.txt
# 20201126-Pro-ter_mTurq2-collection_n3.xlsx
# 20201204-Pro-ter_mTurq2-collection_n5.xlsx
# 20201112-pro-ter_mTurq_contents.xls
# 20201122-Pro-ter_mTurq2-collection_n2.xlsx
# 20201110-Pro-ter_mTurq2-collection_n1.xlsx
# 20201110-Pro-ter_mTurq2-collection_n1.log
# 20201110-Pro-ter_mTurq2-collection_n1_sc.json

# %%
p.load('20201110-Pro-ter_mTurq2-collection_n1.xlsx', '20201112-pro-ter_mTurq_contents.xls')
# Out:
# loading 20201110-Pro-ter_mTurq2-collection_n1.xlsx
#
# Experiment: 20201110-Pro-ter_mTurq2-collection_n1
# ---
# Conditions:
# 	 SC-URA
# Strains:
# 	 POT1-ccdB
# 	 null
# 	 pCLN2-mTurq-tCLN2
# 	 pCLN2-mTurq-tHSP26
# 	 pCLN2-mTurq-tPAB1
# 	 pCLN2-mTurq-tPGK1
# 	 pCLN2-mTurq-tPMA1_long
# 	 pCLN2-mTurq-tRPS13
# 	 pCLN2-mTurq-tRPS3
# 	 pCLN2-mTurq-tSRO9_long
# 	 pCLN2-mTurq-tSUN4
# 	 pCLN2-mTurq-tTOS6
# 	 pHSP26-mTurq-tCLN2
# 	 pHSP26-mTurq-tHSP26
# 	 pHSP26-mTurq-tPAB1
# 	 pHSP26-mTurq-tPGK1
# 	 pHSP26-mTurq-tPMA1_long
# 	 pHSP26-mTurq-tRPS13
# 	 pHSP26-mTurq-tRPS3
# 	 pHSP26-mTurq-tSRO9_long
# 	 pHSP26-mTurq-tSUN4
# 	 pHSP26-mTurq-tTOS6
# 	 pPGK1-mTurq-tCLN2
# 	 pPGK1-mTurq-tHSP26
# 	 pPGK1-mTurq-tPAB1
# 	 pPGK1-mTurq-tPGK1
# 	 pPGK1-mTurq-tPMA1_long
# 	 pPGK1-mTurq-tRPS13
# 	 pPGK1-mTurq-tRPS3
# 	 pPGK1-mTurq-tSRO9_long
# 	 pPGK1-mTurq-tSUN4
# 	 pPGK1-mTurq-tTOS6
# 	 pRPS13-mTurq-tCLN2
# 	 pRPS13-mTurq-tHSP26
# 	 pRPS13-mTurq-tPAB1
# 	 pRPS13-mTurq-tPGK1
# 	 pRPS13-mTurq-tPMA1_long
# 	 pRPS13-mTurq-tRPS13
# 	 pRPS13-mTurq-tRPS3
# 	 pRPS13-mTurq-tSRO9_long
# 	 pRPS13-mTurq-tSUN4
# 	 pRPS13-mTurq-tTOS6
# 	 pRPS3-mTurq-tCLN2
# 	 pRPS3-mTurq-tHSP26
# 	 pRPS3-mTurq-tPAB1
# 	 pRPS3-mTurq-tPGK1
# 	 pRPS3-mTurq-tPMA1_long
# 	 pRPS3-mTurq-tRPS13
# 	 pRPS3-mTurq-tRPS3
# 	 pRPS3-mTurq-tSRO9_long
# 	 pRPS3-mTurq-tSUN4
# 	 pRPS3-mTurq-tTOS6
# 	 pSRO9-mTurq-tCLN2
# 	 pSRO9-mTurq-tHSP26
# 	 pSRO9-mTurq-tPAB1
# 	 pSRO9-mTurq-tPGK1
# 	 pSRO9-mTurq-tPMA1_long
# 	 pSRO9-mTurq-tRPS13
# 	 pSRO9-mTurq-tRPS3
# 	 pSRO9-mTurq-tSRO9_long
# 	 pSRO9-mTurq-tSUN4
# 	 pSRO9-mTurq-tTOS6
# Data types:
# 	 OD
# 	 mTurq-80
# 	 mTurq-60
# Ignored wells:
# 	 None

# %%
#p.r.head()

# %%
#p.r.columns

# %%
#p.s

# %%
#p.plot(y= 'OD', plate= True)
#p.plot(y= 'mTurq-60', plate= True)

# %%
p.correctOD()
# Out:
# 20201110-Pro-ter_mTurq2-collection_n1 :: Correcting for media for OD in SC-URA
# GP Warning: large data set - 2640 datapoints - may slow optimisation and give memory issues
# Fitting dilution data for OD correction for non-linearities
# Using ../../../../data/raw_platereader/promoter_terminator_swaps/mTurq_collection/ODcorrection_Glucose_Haploid.txt

# %%
p.getstats()
# Out:
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: POT1-ccdB in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 4.002461e+02
# hparam[0]= 2.339817e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.099901e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.604399e-03 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.554376e-01 +/- 9.700319e-03 [9.700319e-04]
#  time of max gr= 3.095638e+00 +/- 2.915172e-01 [2.915172e-02]
#   doubling time= 1.951564e+00 +/- 5.283254e-02 [5.283254e-03]
#          max OD= 6.830046e-01 +/- 5.493729e-03 [5.493729e-04]
#        lag time= 1.040270e+00 +/- 7.370422e-02 [7.370422e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pCLN2-mTurq-tCLN2 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.659244e+02
# hparam[0]= 1.499377e+04 [1.000000e-05, 1.000000e+05]
# hparam[1]= 4.717963e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.739107e-01 +/- 4.423578e-03 [4.423578e-04]
#  time of max gr= 3.068112e+00 +/- 2.169523e-01 [2.169523e-02]
#   doubling time= 1.854036e+00 +/- 2.189480e-02 [2.189480e-03]
#          max OD= 7.009595e-01 +/- 9.789403e-04 [9.789403e-05]
#        lag time= 1.050876e+00 +/- 2.455088e-02 [2.455088e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pCLN2-mTurq-tHSP26 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.961704e+02
# hparam[0]= 9.679594e+04 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.931587e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.776586e-01 +/- 2.542411e-03 [2.542411e-04]
#  time of max gr= 3.053292e+00 +/- 1.801125e-01 [1.801125e-02]
#   doubling time= 1.835464e+00 +/- 1.238495e-02 [1.238495e-03]
#          max OD= 6.790039e-01 +/- 9.334349e-04 [9.334349e-05]
#        lag time= 9.136335e-01 +/- 1.519235e-02 [1.519235e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pCLN2-mTurq-tPAB1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.952870e+02
# hparam[0]= 9.999751e+04 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.011104e+02 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.700345e-01 +/- 3.386610e-03 [3.386610e-04]
#  time of max gr= 2.983420e+00 +/- 1.748452e-01 [1.748452e-02]
#   doubling time= 1.873353e+00 +/- 1.712982e-02 [1.712982e-03]
#          max OD= 6.754099e-01 +/- 9.086317e-04 [9.086317e-05]
#        lag time= 8.796467e-01 +/- 2.112513e-02 [2.112513e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pCLN2-mTurq-tPGK1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2
-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS13-mTurq-tPMA1_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
#  Warning: optimization of hyperparameters failed at run 1
# log(max likelihood)= 2.952350e+02
# hparam[0]= 5.442924e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.377828e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.631597e-01 +/- 3.429313e-03 [3.429313e-04]
#  time of max gr= 2.877551e+00 +/- 1.988399e-01 [1.988399e-02]
#   doubling time= 1.908827e+00 +/- 1.800507e-02 [1.800507e-03]
#          max OD= 6.985329e-01 +/- 1.052112e-03 [1.052112e-04]
#        lag time= 8.542205e-01 +/- 1.937602e-02 [1.937602e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS13-mTurq-tRPS13 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.043308e+02
# hparam[0]= 2.605667e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.142814e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.681560e-01 +/- 2.874433e-03 [2.874433e-04]
#  time of max gr= 2.871200e+00 +/- 2.247192e-01 [2.247192e-02]
#   doubling time= 1.882869e+00 +/- 1.466466e-02 [1.466466e-03]
#          max OD= 7.089511e-01 +/- 1.047274e-03 [1.047274e-04]
#        lag time= 1.012917e+00 +/- 1.745214e-02 [1.745214e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS13-mTurq-tRPS3 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.003375e+02
# hparam[0]= 2.897312e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.111418e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.564537e-01 +/- 3.450507e-03 [3.450507e-04]
#  time of max gr= 3.070231e+00 +/- 1.388449e-01 [1.388449e-02]
#   doubling time= 1.944746e+00 +/- 1.879702e-02 [1.879702e-03]
#          max OD= 6.328191e-01 +/- 8.907763e-04 [8.907763e-05]
#        lag time= 7.776230e-01 +/- 2.354391e-02 [2.354391e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS13-mTurq-tSRO9_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.844977e+02
# hparam[0]= 1.723936e+04 [1.000000e-05, 1.000000e+05]
# hparam[1]= 7.077133e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.654022e-01 +/- 3.068436e-03 [3.068436e-04]
#  time of max gr= 2.750510e+00 +/- 2.019727e-01 [2.019727e-02]
#   doubling time= 1.897077e+00 +/- 1.596828e-02 [1.596828e-03]
#          max OD= 7.015433e-01 +/- 1.092648e-03 [1.092648e-04]
#        lag time= 7.030980e-01 +/- 1.897984e-02 [1.897984e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS13-mTurq-tSUN4 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.970734e+02
# hparam[0]= 2.277960e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.087915e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.567971e-01 +/- 2.760491e-03 [2.760491e-04]
#  time of max gr= 3.068112e+00 +/- 2.601746e-01 [2.601746e-02]
#   doubling time= 1.942808e+00 +/- 1.497596e-02 [1.497596e-03]
#          max OD= 6.969276e-01 +/- 9.220632e-04 [9.220632e-05]
#        lag time= 1.115368e+00 +/- 1.735581e-02 [1.735581e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS13-mTurq-tTOS6 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.883558e+02
# hparam[0]= 1.124101e+03 [1.000000e-05, 1.000000e+05]
# hparam[1]= 4.104108e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.486685e-01 +/- 2.803414e-03 [2.803414e-04]
#  time of max gr= 3.085051e+00 +/- 2.185171e-01 [2.185171e-02]
#   doubling time= 1.988112e+00 +/- 1.598252e-02 [1.598252e-03]
#          max OD= 6.647831e-01 +/- 1.045733e-03 [1.045733e-04]
#        lag time= 1.051605e+00 +/- 1.992100e-02 [1.992100e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS3-mTurq-tCLN2 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.027533e+02
# hparam[0]= 2.102413e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.024232e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.696168e-01 +/- 3.656514e-03 [3.656514e-04]
#  time of max gr= 2.886022e+00 +/- 3.063289e-01 [3.063289e-02]
#   doubling time= 1.875496e+00 +/- 1.844914e-02 [1.844914e-03]
#          max OD= 6.934889e-01 +/- 8.228646e-04 [8.228646e-05]
#        lag time= 8.275227e-01 +/- 2.267198e-02 [2.267198e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS3-mTurq-tHSP26 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.998322e+02
# hparam[0]= 4.257632e+03 [1.000000e-05, 1.000000e+05]
# hparam[1]= 5.423655e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.732045e-01 +/- 3.093004e-03 [3.093004e-04]
#  time of max gr= 2.797091e+00 +/- 1.877056e-01 [1.877056e-02]
#   doubling time= 1.857413e+00 +/- 1.537076e-02 [1.537076e-03]
#          max OD= 6.932940e-01 +/- 1.031405e-03 [1.031405e-04]
#        lag time= 9.503491e-01 +/- 1.762780e-02 [1.762780e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS3-mTurq-tPAB1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.787549e+02
# hparam[0]= 4.461980e+02 [1.000000e-05, 1.000000e+05]
# hparam[1]= 2.765443e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.703291e-01 +/- 3.143874e-03 [3.143874e-04]
#  time of max gr= 2.572654e+00 +/- 3.509616e-01 [3.509616e-02]
#   doubling time= 1.871841e+00 +/- 1.591402e-02 [1.591402e-03]
#          max OD= 7.177528e-01 +/- 1.081436e-03 [1.081436e-04]
#        lag time= 8.712489e-01 +/- 1.726466e-02 [1.726466e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS3-mTurq-tPGK1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.026541e+02
# hparam[0]= 2.201964e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.000023e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.852003e-01 +/- 3.020013e-03 [3.020013e-04]
#  time of max gr= 2.579006e+00 +/- 2.750576e-01 [2.750576e-02]
#   doubling time= 1.799557e+00 +/- 1.407949e-02 [1.407949e-03]
#          max OD= 7.120281e-01 +/- 1.179311e-03 [1.179311e-04]
#        lag time= 5.918181e-01 +/- 1.674008e-02 [1.674008e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS3-mTurq-tPMA1_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.982663e+02
# hparam[0]= 5.013729e+04 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.048820e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.696607e-01 +/- 3.295713e-03 [3.295713e-04]
#  time of max gr= 2.852143e+00 +/- 2.062767e-01 [2.062767e-02]
#   doubling time= 1.875239e+00 +/- 1.668235e-02 [1.668235e-03]
#          max OD= 6.978366e-01 +/- 1.100077e-03 [1.100077e-04]
#        lag time= 8.523865e-01 +/- 1.852577e-02 [1.852577e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS3-mTurq-tRPS13 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.055245e+02
# hparam[0]= 2.470264e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.124003e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.797504e-01 +/- 2.930076e-03 [2.930076e-04]
#  time of max gr= 2.771684e+00 +/- 2.378519e-01 [2.378519e-02]
#   doubling time= 1.825379e+00 +/- 1.408610e-02 [1.408610e-03]
#          max OD= 7.040744e-01 +/- 1.120253e-03 [1.120253e-04]
#        lag time= 9.579064e-01 +/- 1.609681e-02 [1.609681e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS3-mTurq-tRPS3 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.024087e+02
# hparam[0]= 2.560886e+03 [1.000000e-05, 1.000000e+05]
# hparam[1]= 5.004378e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.840282e-01 +/- 3.238074e-03 [3.238074e-04]
#  time of max gr= 2.941072e+00 +/- 1.523765e-01 [1.523765e-02]
#   doubling time= 1.805066e+00 +/- 1.520487e-02 [1.520487e-03]
#          max OD= 7.074776e-01 +/- 1.049587e-03 [1.049587e-04]
#        lag time= 9.537367e-01 +/- 1.816919e-02 [1.816919e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS3-mTurq-tSRO9_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.010581e+02
# hparam[0]= 4.532155e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.318029e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.683463e-01 +/- 2.878782e-03 [2.878782e-04]
#  time of max gr= 2.991889e+00 +/- 2.131175e-01 [2.131175e-02]
#   doubling time= 1.881896e+00 +/- 1.469352e-02 [1.469352e-03]
#          max OD= 7.087962e-01 +/- 1.183796e-03 [1.183796e-04]
#        lag time= 9.184183e-01 +/- 1.859952e-02 [1.859952e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS3-mTurq-tSUN4 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.012852e+02
# hparam[0]= 1.316586e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.647360e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.599929e-01 +/- 2.986320e-03 [2.986320e-04]
#  time of max gr= 3.129515e+00 +/- 2.330602e-01 [2.330602e-02]
#   doubling time= 1.925579e+00 +/- 1.594923e-02 [1.594923e-03]
#          max OD= 6.961897e-01 +/- 1.048377e-03 [1.048377e-04]
#        lag time= 9.433652e-01 +/- 1.945870e-02 [1.945870e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pRPS3-mTurq-tTOS6 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.568335e+02
# hparam[0]= 5.053184e+03 [1.000000e-05, 1.000000e+05]
# hparam[1]= 7.125783e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 3.254580e-05 [1.000000e-05, 1.000000e+02]
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.594016e-01 +/- 3.240183e-03 [3.240183e-04]
#  time of max gr= 3.006710e+00 +/- 1.372211e-01 [1.372211e-02]
#   doubling time= 1.928772e+00 +/- 1.742640e-02 [1.742640e-03]
#          max OD= 6.910133e-01 +/- 1.470645e-03 [1.470645e-04]
#        lag time= 1.011085e+00 +/- 2.146253e-02 [2.146253e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pSRO9-mTurq-tCLN2 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.880239e+02
# hparam[0]= 2.700269e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 9.805164e+00 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.790072e-01 +/- 4.196775e-03 [4.196775e-04]
#  time of max gr= 3.027884e+00 +/- 1.707072e-01 [1.707072e-02]
#   doubling time= 1.829073e+00 +/- 2.012508e-02 [2.012508e-03]
#          max OD= 6.770166e-01 +/- 1.205761e-03 [1.205761e-04]
#        lag time= 1.006423e+00 +/- 2.452503e-02 [2.452503e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pSRO9-mTurq-tHSP26 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.035548e+02
# hparam[0]= 1.526350e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.023362e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.783447e-01 +/- 3.687844e-03 [3.687844e-04]
#  time of max gr= 3.023649e+00 +/- 1.558237e-01 [1.558237e-02]
#   doubling time= 1.832226e+00 +/- 1.786274e-02 [1.786274e-03]
#          max OD= 6.962759e-01 +/- 1.187568e-03 [1.187568e-04]
#        lag time= 1.021343e+00 +/- 2.116001e-02 [2.116001e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pSRO9-mTurq-tPAB1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
#  Warning: optimization of hyperparameters failed at run 1
# log(max likelihood)= 2.992800e+02
# hparam[0]= 5.615371e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.326322e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.626468e-01 +/- 3.190686e-03 [3.190686e-04]
#  time of max gr= 2.938955e+00 +/- 2.102054e-01 [2.102054e-02]
#   doubling time= 1.911503e+00 +/- 1.673914e-02 [1.673914e-03]
#          max OD= 7.020839e-01 +/- 1.358795e-03 [1.358795e-04]
#        lag time= 1.016187e+00 +/- 1.732932e-02 [1.732932e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pSRO9-mTurq-tPGK1 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.000135e+02
# hparam[0]= 2.820116e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.080783e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.750420e-01 +/- 3.533668e-03 [3.533668e-04]
#  time of max gr= 2.941072e+00 +/- 2.028579e-01 [2.028579e-02]
#   doubling time= 1.848349e+00 +/- 1.742765e-02 [1.742765e-03]
#          max OD= 6.833753e-01 +/- 1.006544e-03 [1.006544e-04]
#        lag time= 8.002755e-01 +/- 2.172672e-02 [2.172672e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pSRO9-mTurq-tPMA1_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.076420e+02
# hparam[0]= 5.527944e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.446460e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.566817e-01 +/- 3.214777e-03 [3.214777e-04]
#  time of max gr= 2.896608e+00 +/- 1.609188e-01 [1.609188e-02]
#   doubling time= 1.943480e+00 +/- 1.755597e-02 [1.755597e-03]
#          max OD= 7.002027e-01 +/- 1.310830e-03 [1.310830e-04]
#        lag time= 8.259284e-01 +/- 2.232160e-02 [2.232160e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pSRO9-mTurq-tRPS13 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.032962e+02
# hparam[0]= 5.243411e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.373927e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.682249e-01 +/- 2.969625e-03 [2.969625e-04]
#  time of max gr= 2.905077e+00 +/- 1.695999e-01 [1.695999e-02]
#   doubling time= 1.882524e+00 +/- 1.514154e-02 [1.514154e-03]
#          max OD= 6.998066e-01 +/- 1.389236e-03 [1.389236e-04]
#        lag time= 9.121949e-01 +/- 1.722477e-02 [1.722477e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pSRO9-mTurq-tRPS3 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 3.003702e+02
# hparam[0]= 2.483089e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.116844e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.678328e-01 +/- 3.362410e-03 [3.362410e-04]
#  time of max gr= 2.970715e+00 +/- 2.404014e-01 [2.404014e-02]
#   doubling time= 1.884565e+00 +/- 1.717294e-02 [1.717294e-03]
#          max OD= 7.113402e-01 +/- 1.233233e-03 [1.233233e-04]
#        lag time= 9.705568e-01 +/- 1.983269e-02 [1.983269e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pSRO9-mTurq-tSRO9_long in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.958953e+02
# hparam[0]= 1.838821e+03 [1.000000e-05, 1.000000e+05]
# hparam[1]= 4.566062e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.662882e-01 +/- 3.182174e-03 [3.182174e-04]
#  time of max gr= 3.150689e+00 +/- 2.165065e-01 [2.165065e-02]
#   doubling time= 1.892497e+00 +/- 1.639766e-02 [1.639766e-03]
#          max OD= 6.945612e-01 +/- 1.159528e-03 [1.159528e-04]
#        lag time= 1.049588e+00 +/- 1.918069e-02 [1.918069e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pSRO9-mTurq-tSUN4 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.963436e+02
# hparam[0]= 9.999993e+04 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.062992e+02 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.557190e-01 +/- 2.902915e-03 [2.902915e-04]
#  time of max gr= 3.074466e+00 +/- 1.808565e-01 [1.808565e-02]
#   doubling time= 1.948710e+00 +/- 1.588473e-02 [1.588473e-03]
#          max OD= 6.856004e-01 +/- 1.347319e-03 [1.347319e-04]
#        lag time= 8.638665e-01 +/- 2.003030e-02 [2.003030e-03]
# Fitting OD for 20201110-Pro-ter_mTurq2-collection_n1:: pSRO9-mTurq-tTOS6 in SC-URA
# Taking natural logarithm of the data.
# Fitting measurement errors.
# Using a (twice differentiable) Matern covariance function.
# hparam[0] determines the amplitude of variation
# hparam[1] determines the stiffness
# hparam[2] determines the variance of the measurement error
# log(max likelihood)= 2.867554e+02
# hparam[0]= 4.220191e+00 [1.000000e-05, 1.000000e+05]
# hparam[1]= 1.180493e+01 [1.000000e-04, 1.000000e+04]
# hparam[2]= 1.000000e-05 [1.000000e-05, 1.000000e+02]
# Warning: hyperparameter 2 is at a lower bound
#
# Calculating statistics with 100 samples
# 	(displaying mean +/- standard deviation [standard error])
#
#          max gr= 3.601301e-01 +/- 3.456761e-03 [3.456761e-04]
#  time of max gr= 3.265024e+00 +/- 2.099891e-01 [2.099891e-02]
#   doubling time= 1.924890e+00 +/- 1.841696e-02 [1.841696e-03]
#          max OD= 6.787450e-01 +/- 9.434168e-04 [9.434168e-05]
#        lag time= 1.078774e+00 +/- 2.167308e-02 [2.167308e-03]

# %%
#p.sc[['experiment','strain', 'max gr', 'max gr var']].head()

# %%
#p.plot(y= 'gr', hue= 'strain')

# %%
p.correctauto(['mTurq-60'], refstrain= 'POT1-ccdB')
# Out:
# Using POT1-ccdB as the reference
# Correcting autofluorescence
# 20201110-Pro-ter_mTurq2-collection_n1:: Processing reference strain POT1-ccdB for mTurq-60 in SC-URA

# %%
p.s[["experiment", "strain", "time", "OD mean", "c-mTurq-60", "c-mTurq-60perod", "gr"]].to_csv("../../../../data/norm_platereader/promoter_terminator_swaps/mTurq_collection/pro-mTurq-ter_swaps_OD_and_mTurq.csv", mode = "a")
p.sc[["experiment", "strain", "max gr", "time of max gr"]].to_csv("../../../../data/norm_platereader/promoter_terminator_swaps/mTurq_collection/pro-mTurq-ter_swaps_max_gr.csv", mode = "a")

# %%
e= '20201110-Pro-ter_mTurq2-collection_n1'
# store results as an array of dictionaries to eventually convert into a dataframe
results= []
for s in p.allstrains[e]:
        # find the time of local maximum growth rate for the condition
        tm= p.sc.query('strain == @s')['time of local max gr'].values[0]
        # take the relevant sub-dataframe for the condition
        df= p.s.query('strain == @s')
        # find GPF mean at time tm
        i= np.argmin(np.abs(df['time'].values - tm))
        results.append({'c-mTurq-60 per OD at max local gr' : df['c-mTurq-60perod'][df.index[i]],
                     'strain' : s})
# convert to dataframe
rdf= pd.DataFrame(results)
# add to existing dataframe by experiment, condition, and strain
p.sc= pd.merge(p.sc, rdf, how= 'outer')

# %%
#p.sc[['strain','c-mTurq-60 per OD at max local gr']].to_csv("../../../../data/norm_platereader/promoter_terminator_swaps/mTurq_collection/pro-mTurq-ter_swaps_n=1.csv")

# %%
# Out:
# Object `to_csv` not found.
